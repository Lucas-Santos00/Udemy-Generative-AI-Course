# %% [markdown]
# ## Tokenization Practicals

# %%
corpus = """Hello welcome, to Kraish Naik's NLP tutorial. Plese watch the entire course! To become an export in NLP"""

# %%
print(corpus)
# Out:
# Hello welcome, to Kraish Naik's NLP tutorial.
# Plese watch the entire course! To become an export in NLP

# %%
##  Tokenization
## Sentence-->paragraphs
from nltk.tokenize import sent_tokenize
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/lucassantos/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
corpus = """Hello welcome, to Kraish Naik's NLP tutorial. Plese watch the entire course! To become an export in NLP"""
sent_tokenize(corpus)
# Out:
# ["Hello welcome, to Kraish Naik's NLP tutorial.",
#  'Plese watch the entire course!',
#  'To become an export in NLP']

# %%
# Tonkenization
## converting paragraphs into words
from nltk.tokenize import word_tokenize
word_tokenize(corpus)
# Out:
# ['Hello',
#  'welcome',
#  ',',
#  'to',
#  'Kraish',
#  'Naik',
#  "'s",
#  'NLP',
#  'tutorial',
#  '.',
#  'Plese',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'To',
#  'become',
#  'an',
#  'export',
#  'in',
#  'NLP']

# %%
from nltk.tokenize import wordpunct_tokenize

wordpunct_tokenize(corpus)
# Out:
# ['Hello',
#  'welcome',
#  ',',
#  'to',
#  'Kraish',
#  'Naik',
#  "'",
#  's',
#  'NLP',
#  'tutorial',
#  '.',
#  'Plese',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'To',
#  'become',
#  'an',
#  'export',
#  'in',
#  'NLP']

# %%
from nltk.tokenize import TreebankWordTokenizer
tokenizer = TreebankWordTokenizer()
tokenizer.tokenize(corpus)
# Out:
# ['Hello',
#  'welcome',
#  ',',
#  'to',
#  'Kraish',
#  'Naik',
#  "'s",
#  'NLP',
#  'tutorial.',
#  'Plese',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'To',
#  'become',
#  'an',
#  'export',
#  'in',
#  'NLP']
