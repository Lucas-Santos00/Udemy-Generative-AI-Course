# %% [markdown]
# Package and Modules in Python

# %%
## Modulos e pacotes são usados para organizer e reusar códigos.

import math ## Import de um pacote, possuindo várias funções matemáticas
## from math import *
math.sqrt(16)
# Out:
# 4.0

# %%
## Import only sqrt and pi functions

from math import sqrt, pi
print(sqrt(16)) ## Podemos usar diretamente a função, sem precisar acessar math antes
print(pi)
# Out:
# 4.0
# 3.141592653589793

# %%
## numpy manitula arrays, será usada como exemplo
## Ela precisa ser instalada via pip (pip install numpy)
import numpy as np ## as seria um alias, podemos acessar todas as funções usando np.funçao, inves de precisar escrever numpy

# %%
## Criar um módulo/pacote
## Tudo deve estar na mesma pasta!
## __init__.py -> Nome usado em arquivos especiais em pytoh (Packages) e usado para inicializar sesus namespaces

## __init__.py
''' Teste Doc ''' ## Forma de documentar o pacote



## myPackage.py
def addition(a,b):
    return a+b

## arquivo.py
## from package.myPackage import addition
## from package.subpackage.mySubpkage impot myFunction -> Para subpackages

# %% [markdown]
# Standards Python libraries
#
# - array -> Usado para criar arrays tipadas, onde todos os itens contendo dentro dela devem ser do mesmo tipo
# myArray=array.array('i', [1,2,3,4])
#
# - math -> Calculos matemáticos
#
# - Random -> usado para criar números randomincos
#
# - OS -> Usado para acesso a arquivos e pastas do sistema operacional
#
# - shutil -> Usado para operações de alto nível para manipulação de arquivos e diretórios, como copiar, mover, renomear e excluir arquivos, bem como criar e remover diretórios
#
# - json -> Usado para manipular arquivos Json
#
# - csv -> Usado apra arquivos csv
#
# - datetime -> Usado para manipular data
#
# - time -> Usado para manipular horários
#
# - re -> Expressões regulares
