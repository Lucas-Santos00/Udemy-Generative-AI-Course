# %%
## Defining a variable with a value of 100
a=100

# %%
# Declaring and assigning a variables

age= 25 #integer variable
name = "Alice" #string variable
height = 5.5 #float variable
is_student = True #boolean variable

print("Age:", age)
print("Name:", name)
print("Height:", height)
print("Is Student:", is_student)
# Out:
# Age: 25
# Name: Alice
# Height: 5.5
# Is Student: True

# %%
# Namiong conventions
# Use lowercase letters, underscores for spaces, and avoid starting with a number
# casesensitive, so 'age' and 'Age' are different variables
# Should be descriptive and meaningful
# Must start with a letter or underscore, followed by letters, numbers, or underscores

# %%
# Type checking and conversaion
print("Type of age:", type(age))

# Type conversion examples
age_str = str(age)  # Convert integer to string
print(type(age_str), age_str)
# Out:
# Type of age: <class 'int'>
# <class 'str'> 25

# %%
# Dynamic typing
# Python allows thhe of the cariable to change as the program executes
var = 10 #Int
print(var, type(var))
var=10.57 #Float
print(var, type(var))
# Out:
# 10 <class 'int'>
# 10.57 <class 'float'>

# %%
# Input

user_input = int(input("Enter your favorite number: "))
print("You entered:", user_input)
# Out:
# You entered: 5

# %%
## Simple calculator

num1 = input("Enter first number: ")
num2 = input("Enter second number: ")

sum_result = float(num1) + float(num2)
diferrence_result = float(num1) - float(num2)
product_result = float(num1) * float(num2)
division_result = float(num1) / float(num2)

print("Sum:", sum_result)
print("Difference:", diferrence_result)
print("Product:", product_result)
print("Division:", division_result)
# Out:
# Sum: 77.0
# Difference: -53.0
# Product: 780.0
# Division: 0.18461538461538463
