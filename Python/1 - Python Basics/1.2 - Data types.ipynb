# %%
# Classificação de tipos de dados em Python. De acordo com cada tipo de dado temos difernetes tamanhos de memória e diferentes formas de manipulação.
# Tipo de dados podem ser usados, também, para previnir bugs e erros de lógica.

## Basic Data Types in Python:
# Integers 
# Floats
# Strings
# Booleans

## Advanced Data Types in Python:
# Lists
# Tuples
# Sets
# Dictionaries
