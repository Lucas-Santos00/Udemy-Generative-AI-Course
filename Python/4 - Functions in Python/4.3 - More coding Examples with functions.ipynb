# %%
def temperature_conversion(celsius):
    f = (celsius*1.8) + 32
    print(f"{celsius} Celsius is {f} Fahrenheit")

temperature_conversion(0)
temperature_conversion(25)
temperature_conversion(100)
# Out:
# 0 Celsius is 32.0 Fahrenheit
# 25 Celsius is 77.0 Fahrenheit
# 100 Celsius is 212.0 Fahrenheit
